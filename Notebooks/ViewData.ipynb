# %%
import json
import os

# %%
fileList = ['../Datasets/' + f for f in os.listdir('../Datasets') if f.endswith('.json')]

# %%
fileList
# Out:
# ['../Datasets/2015-01-01-15.json']

# %%
for f in fileList:
    fileObj = open(f,)
    data = json.load(fileObj)
    fileObj.close()

# %%
data
# Out:
# [{u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/665991?',
#    u'gravatar_id': u'',
#    u'id': 665991,
#    u'login': u'petroav',
#    u'url': u'https://api.github.com/users/petroav'},
#   u'created_at': u'2015-01-01T15:00:00Z',
#   u'id': u'2489651045',
#   u'payload': {u'description': u"Solution to homework and assignments from MIT's 6.828 (Operating Systems Engineering). Done in my spare time.",
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': u'master',
#    u'ref_type': u'branch'},
#   u'public': True,
#   u'repo': {u'id': 28688495,
#    u'name': u'petroav/6.828',
#    u'url': u'https://api.github.com/repos/petroav/6.828'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/3854017?',
#    u'gravatar_id': u'',
#    u'id': 3854017,
#    u'login': u'rspt',
#    u'url': u'https://api.github.com/users/rspt'},
#   u'created_at': u'2015-01-01T15:00:01Z',
#   u'id': u'2489651051',
# ...
